# %%
from datasets import load_dataset
from pprint import pprint

# %%
ds = load_dataset("cfilt/PUB")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
df = ds["train"].to_pandas()

# %%
pprint(df.loc[0,:].to_dict())
# Out:
# {'correct answer': 'Direct answer',
#  'id': '0',
#  'options': array(['Direct answer', 'Indirect answer'], dtype=object),
#  'pretext': 'Context: X and Y are colleagues who are leaving work on a Friday '
#             'at the same time.\n'
#             'Question: Do you want me to give you a lift home?\n'
#             'Response: I want me to give I a lift home .\n'}
